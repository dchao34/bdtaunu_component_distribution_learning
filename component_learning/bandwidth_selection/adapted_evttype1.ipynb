# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from kde_visual_utils import plot_data2d, plot_contour2d

# %%
fig = plt.figure(figsize=(24,24))

ax = fig.add_subplot(2,2,1)
plot_data2d('adapted_evttype1_scatter.csv', ax=ax, title=r'input sample', xlim=[-0.005,0.11], ylim=[-0.05,1.05])
ax = fig.add_subplot(2,2,3)
plot_contour2d('adapted_evttype1_kde.csv', ax=ax, title=r'cross validated', 
               nlevels=10, colorbar=False, contour_fmt='%1.0f')
ax = fig.add_subplot(2,2,4)
plot_contour2d('adapted_evttype1_akde.csv', ax=ax, title=r'cross validated and adapted', 
               nlevels=10, colorbar=False, contour_fmt='%1.0f')

# %%
fig = plt.figure(figsize=(10,8))

ax = fig.add_subplot(1,1,1)
plot_contour2d('adapted_evttype1_gridsearch.csv', ax=ax, title=r'least squares cross validation score', 
               nlevels=30, nlevels_f=200, colorbar=True, cmap=plt.cm.YlOrRd_r, contour_fmt='%1.2f')
# Out:
# /local/dchao/software/anaconda2/lib/python2.7/site-packages/matplotlib/contour.py:370: RuntimeWarning: invalid value encountered in true_divide
#   dist = np.add.reduce(([(abs(s)[i] / L[i]) for i in range(xsize)]), -1)
